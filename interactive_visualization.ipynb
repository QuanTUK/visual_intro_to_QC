# %%
from qc_education_package import InteractiveDCNViewer

viewer = InteractiveDCNViewer(num_qubits=3)

# Render a large, highly-detailed 12x8 inch plot bounded inside a 900px Jupyter container
viewer.display(figsize=(12.0, 8.0), ui_width='900px')
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Gate:', layout=Layout(width='180px'), options=('H', 'X', '…

# %%
from qc_education_package import ChallengeDCNViewer

# Initialize the student challenge: Go from |-> to |0>
viewer = ChallengeDCNViewer(
    num_qubits=1,
    initial_state=[1, -1],  # 1/sqrt(2) (|0> - |1>)
    target_state=[1, 0]     # |0>
)

viewer.display()
# Out:
# VBox(children=(HTML(value="<h2 style='text-align: center; color: #e74c3c;'>Status: Incomplete ❌</h2>"), HBox(c…
